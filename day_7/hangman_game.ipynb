# %%
#step 1
import random
word_list  = ["ardvark", "baboon", "camel"]
word_l = random.choice(word_list)
guess = input("Guess a letter:")

for word in word_l:
    for l in word:
        if guess == l:
            print("Right")
        else:
            print("Wrong")
# Out:
# Wrong
# Right
# Wrong
# Wrong
# Wrong

# %%
import random
word_list  = ["ardvark", "baboon", "camel"]
word_l = random.choice(word_list)
guess = input("Guess a letter:").lower()
display = []

print(f"Solution is {word_l}")

for i in word_l:
    display += "_"

word_length = len(word_l)
total = word_length

for i in range(word_length):
    if guess == word_l[i]:
        display[i] = guess
        total -= 1
        if total == 0:
            print("'You've won")


print(display)
# Out:
# Solution is baboon
# ['_', 'a', '_', '_', '_', '_']

# %%
#step 3
import random
word_list  = ["ardvark", "baboon", "camel"]
word_l = random.choice(word_list)

display = []

print(f"Solution is {word_l}")

for i in word_l:
    display += "_"

word_length = len(word_l)
total = word_length+1

end_of_game = False

while end_of_game == False:
    guess = input("Guess a letter:").lower()
    for i in range(word_length):
        letter = word_l[i]

        if guess == word_l[i]:
            display[i] = guess
            total -= 1
    print(display)
    if "_" not in display:
        end_of_game = True
        print("You win.")
# Out:
# Solution is camel
# ['_', 'a', '_', '_', '_']
# ['c', 'a', '_', '_', '_']
# ['c', 'a', 'm', '_', '_']
# ['c', 'a', 'm', 'e', '_']
# ['c', 'a', 'm', 'e', 'l']
# You win.

# %%
#step 4
stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

import random
word_list  = ["ardvark", "baboon", "camel"]
word_l = random.choice(word_list)

display = []

print(f"Solution is {word_l}")

for i in word_l:
    display += "_"

word_length = len(word_l)

end_of_game = False

lives = 6

while end_of_game == False:
    guess = input("Guess a letter:").lower()
    for i in range(word_length):
      letter = word_l[i]

      if guess == word_l[i]:
        display[i] = guess

    if guess not in word_l:
      lives -= 1
      if lives == 0:
         end_of_game = True
         print("You lose.")

    print(f"{' '.join(display)}")

    if "_" not in display:
        end_of_game = True
        print("You win.")
    
    print(stages[lives])
# Out:
# Solution is camel
# _ a _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# ...
#
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# ...
#
# You lose.
# _ a _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# ...

# %%
#stage 5
#step 4
from hangman_art import stages
import random
word_list  = ["ardvark", "baboon", "camel"]
word_l = random.choice(word_list)

display = []

print(f"Solution is {word_l}")

for i in word_l:
    display += "_"

word_length = len(word_l)

end_of_game = False

lives = 6

while end_of_game == False:
    guess = input("Guess a letter:").lower()
    if guess in display:
       print(f"You already guessed {guess}")

    for i in range(word_length):
      letter = word_l[i]

      if guess == word_l[i]:
        display[i] = guess

    if guess not in word_l:
      lives -= 1
      if lives == 0:
         end_of_game = True
         print("You lose.")

    print(f"{' '.join(display)}")

    if "_" not in display:
        end_of_game = True
        print("You win.")
    
    print(stages[lives])
# Out:
# Solution is camel
# c _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# c a _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# c a m _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# c a m e _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
#
# c a m e l
# You win.
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# ...
